# %% [markdown]
# 2025MCM - problem C

# %%
import pandas as pd

# Example of loading data
athletes_data = pd.read_csv('2025_Problem_C_Data/summerOly_athletes.csv')
medal_counts_data = pd.read_csv('2025_Problem_C_Data/summerOly_medal_counts.csv')
hosts_data = pd.read_csv('2025_Problem_C_Data/summerOly_hosts.csv')
programs_data = pd.read_csv('2025_Problem_C_Data/summerOly_programs.csv',encoding = 'latin1')
data_dictionary = pd.read_csv('2025_Problem_C_Data/data_dictionary.csv', encoding = 'latin1')
database = [athletes_data, medal_counts_data, hosts_data, programs_data, data_dictionary,]

# %%
for data in database:
    print("-------")
    data.info()
# Out:
# -------
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 252565 entries, 0 to 252564
# Data columns (total 9 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Name    252565 non-null  object
#  1   Sex     252565 non-null  object
#  2   Team    252565 non-null  object
#  3   NOC     252565 non-null  object
#  4   Year    252565 non-null  int64
#  5   City    252565 non-null  object
#  6   Sport   252565 non-null  object
#  7   Event   252565 non-null  object
#  8   Medal   252565 non-null  object
# dtypes: int64(1), object(8)
# memory usage: 17.3+ MB
# -------
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1435 entries, 0 to 1434
# Data columns (total 7 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Rank    1435 non-null   int64
#  1   NOC     1435 non-null   object
#  2   Gold    1435 non-null   int64
#  3   Silver  1435 non-null   int64
#  4   Bronze  1435 non-null   int64
# ...

# %% [markdown]
# ## Note for 2501896
#
# - develop a model to forecast:
#   1. 2028 medal counts per country
#   2. First time medal-winning probability for nations
#   3. Sport-event structure's impact on medal distribution, including identification of national dominance events
#   4. Quantification of host advantage
#
# - Statisically validate coach replacement effect on medal changes to quantify the great coach contributions
# - Identify the non-traditional factors influencing medal allocations
# - insight(s) can inform country Olympic committees.
#
# the project's work:
# ![image.png](attachment:image.png)

# %%
athletes_data.NOC.head(5)
# Out:
# 0    CHN
# 1    CHN
# 2    DEN
# 3    DEN
# 4    NED
# Name: NOC, dtype: object

# %%
# preprocessing
# feature engineering
